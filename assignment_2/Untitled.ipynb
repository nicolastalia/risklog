# %%
# Import the required packages
# Import packages
import numpy as np
import xpress as xp
import pandas as pd
import time
from functions import allocator
from functions import order_modifier
from functions import swaper
from shorthest_path import shortest_path
from shorthest_path import distance
from collections import Counter

# %%
# Import data file of distances
distances_df = pd.read_excel('Distance Matrix 1.xlsx', sheet_name = "Sheet1")

# Load in the data file of orders
orders = pd.read_excel('OrderList.xlsx', sheet_name = "Orders")

# Drop the order numbers
orders = orders.drop(columns = "Order No.")

# %%
# Run the test

# Define start time
start = time.time()

# Run the function for the above order list (only first 20 for computation time)
tot_distance = distance(orders, distances_df)

# Define end time
end = time.time()

# Print outcome
print()
print(f"The total distance is {tot_distance} metres")
print(f"The run time of the function is {round(end - start, 4)} seconds")
# Out:
# Using the license file found in your Xpress installation. If you want to use this license and no longer want to see this message, use the following code before using the xpress module:
#   xpress.init('/Applications/FICO Xpress/xpressmp/bin/xpauth.xpr')
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 120KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 120KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  42.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         42.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           42.000000    42.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.200000000000000e+01
# Final MIP bound                       : 4.200000000000000e+01
#   Solution time / primaldual integral :      0.02s/ 92.629055%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 124KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 124KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.80e+01] / [ 1.00e+00,  1.80e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    34.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  34.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 10 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.400000000000000e+01
# Final MIP bound                       : 3.400000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 100.000000%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 126KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 126KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 4.00e+00,  2.00e+01] / [ 4.00e+00,  2.00e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    64.000000   Time:   0.00    Heuristic: e ***
#  *** Solution found:    50.000000   Time:   0.00    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  48.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 22 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     22         48.000000      D      0     0        .000000     0
# Dual solved problem
#   22 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.800000000000001e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a           48.000000    48.000000      3                 -0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.800000000000000e+01
# Final MIP bound                       : 4.800000000000001e+01
#   Solution time / primaldual integral :      0.02s/ 92.464490%
#   Number of solutions found / nodes   :         3 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 129KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 129KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  18.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         18.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.800000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           18.000000    18.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 1.800000000000000e+01
# Final MIP bound                       : 1.800000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 44.364992%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 132KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 132KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 3.00e+00,  1.90e+01] / [ 3.00e+00,  1.90e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    51.000000   Time:   0.00    Heuristic: e ***
#  *** Solution found:    48.000000   Time:   0.00    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  46.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 22 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     22         46.000000      D      0     0        .000000     0
# Dual solved problem
#   22 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.600000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a           46.000000    46.000000      3                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.600000000000000e+01
# Final MIP bound                       : 4.600000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 60.328653%
#   Number of solutions found / nodes   :         3 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 135KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 135KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.60e+01] / [ 1.00e+00,  1.60e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    38.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 18 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     18         36.000000      D      0     0        .000000     0
# Dual solved problem
#   18 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.600000000000001e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a           36.000000    36.000000      2                 -0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000001e+01
#   Solution time / primaldual integral :      0.02s/ 86.791684%
#   Number of solutions found / nodes   :         2 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 138KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 138KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.80e+01] / [ 1.00e+00,  1.80e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    66.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  32.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 19 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     19         32.000000      D      0     0        .000000     0
# Dual solved problem
#   19 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     66.000000    32.000000      1     33      0   51.52%      12      0
#    2  K     66.000000    32.000000      1      9     28   51.52%       6      0
#    3  K     66.000000    32.000000      1      2      8   51.52%       6      0
#    4  K     66.000000    32.000000      1      7      3   51.52%       7      0
#    5  K     66.000000    32.000000      1      2      6   51.52%       7      0
# b           56.000000    32.000000      2                 42.86%       0      0
#    6  K     56.000000    32.000000      2      1      3   42.86%       8      0
#    7  K     56.000000    32.000000      2      1      0   42.86%       8      0
# b           44.000000    32.000000      3                 27.27%       0      0
#    8  K     44.000000    32.000000      3      3      2   27.27%       9      0
#    9  K     44.000000    32.000000      3      2      2   27.27%       9      0
#   10  K     44.000000    32.000000      3      1      2   27.27%       8      0
#   11  K     44.000000    32.000000      3      0      1   27.27%       7      0
#   12  G     44.000000    32.000000      3      7      0   27.27%       7      0
#   13  G     44.000000    32.000000      3      6     14   27.27%       7      0
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 5
# Cut elements in the matrix : 48
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:      42 rows      24 columns       129 elements
# Presolve dropped   :      10 rows      11 columns        27 elements
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    42.000000   Time:   0.06    Heuristic: e ***
# Crash basis containing 4 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    179         34.000000      D      0     0        .000000     0
# Optimal solution found
# Dual solved problem
#   179 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.400000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.200000000000000e+01
# Final MIP bound                       : 4.200000000000000e+01
#   Solution time / primaldual integral :      0.07s/ 39.747705%
#   Number of solutions found / nodes   :         4 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 140KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 140KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  32.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         32.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           32.000000    32.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.200000000000000e+01
# Final MIP bound                       : 3.200000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 61.515763%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 142KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 142KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  38.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         38.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.800000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           38.000000    38.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.800000000000000e+01
# Final MIP bound                       : 3.800000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 72.429719%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 145KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 145KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 2.00e+00,  2.20e+01] / [ 2.00e+00,  2.20e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    84.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  42.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 20 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     20         42.000000      D      0     0        .000000     0
# Dual solved problem
#   20 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.200000000000001e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     84.000000    42.000000      1     34      0   50.00%      12      0
#    2  K     84.000000    42.000000      1      9     29   50.00%       6      0
#    3  K     84.000000    42.000000      1      3      8   50.00%       6      0
#    4  K     84.000000    42.000000      1      9      4   50.00%       7      0
#    5  K     84.000000    42.000000      1      3      8   50.00%       7      0
#    6  K     84.000000    42.000000      1      1      4   50.00%       8      0
#    7  K     84.000000    42.000000      1      1      0   50.00%       8      0
# b           60.000000    42.000000      2                 30.00%       0      0
#    8  K     60.000000    42.000000      2      3      2   30.00%       9      0
#    9  K     60.000000    42.000000      2      2      2   30.00%       9      0
#   10  K     60.000000    42.000000      2      1      2   30.00%       8      0
#   11  K     60.000000    42.000000      2      0      1   30.00%       7      0
#   12  G     60.000000    42.000000      2      6      0   30.00%       7      0
#   13  G     60.000000    42.000000      2      6     10   30.00%       7      0
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 8
# Cut elements in the matrix : 91
#
# Starting tree search.
# Deterministic mode with up to 4 running threads and up to 8 tasks.
# Heap usage: 3433KB (peak 5916KB, 1068KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1    60.000000    42.800000      2      2      1   28.67%       7      0
#        2    60.000000    42.800000      2      2      3   28.67%      13      0
#        3    60.000000    42.800000      2      2      3   28.67%      13      0
# b      4    46.000000    42.800000      3      2      4    6.96%       0      0
#        6    46.000000    42.800000      3      2      4    6.96%      13      0
#        7    46.000000    45.000005      3      1      1    2.17%       2      0
#        8    46.000000    45.000005      3      1      3    2.17%       1      0
#        9    46.000000    45.000005      3      0      1    2.17%       2      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.600000000000000e+01
# Final MIP bound                       : 4.600000000000000e+01
#   Solution time / primaldual integral :      0.08s/ 34.145008%
#   Number of solutions found / nodes   :         3 /         9
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:09, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 147KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 147KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.50e+01] / [ 1.00e+00,  1.50e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    64.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  34.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 18 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     18         34.000000      D      0     0        .000000     0
# Dual solved problem
#   18 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.400000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     64.000000    34.000000      1     33      0   46.88%      12      0
#    2  K     64.000000    34.000000      1      9     28   46.88%       6      0
#    3  K     64.000000    34.000000      1      2      8   46.88%       6      0
#    4  K     64.000000    34.000000      1      7      3   46.88%       7      0
#    5  K     64.000000    34.000000      1      2      6   46.88%       7      0
#    6  K     64.000000    34.000000      1      1      3   46.88%       8      0
#    7  K     64.000000    34.000000      1      1      0   46.88%       8      0
# b           42.000000    34.000000      2                 19.05%       0      0
#    8  K     42.000000    34.000000      2      3      2   19.05%       9      0
#    9  K     42.000000    34.000000      2      2      2   19.05%       9      0
#   10  K     42.000000    34.000000      2      1      2   19.05%       8      0
#   11  K     42.000000    34.000000      2      0      1   19.05%       7      0
#   12  G     42.000000    34.000000      2      6      0   19.05%       7      0
#   13  G     42.000000    34.000000      2      6     12   19.05%       7      0
#
# Cuts in the matrix         : 6
# Cut elements in the matrix : 63
#
# Performing root presolve...
#
# Reduced problem has:      43 rows      23 columns       139 elements
# Presolve dropped   :      10 rows      12 columns        74 elements
# Presolve tightened :         1 elements
# Will try to keep branch and bound tree memory usage below 7.5GB
# Crash basis containing 4 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     57         34.000000      D      0     0        .000000     0
# Optimal solution found
# Dual solved problem
#   57 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.400000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     42.000000    34.000000      2      5      5   19.05%       6      0
#    2  K     42.000000    34.000000      2     39     34   19.05%       8      0
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 11
# Cut elements in the matrix : 75
#
# Starting tree search.
# Deterministic mode with up to 4 running threads and up to 8 tasks.
# Heap usage: 3425KB (peak 6176KB, 1070KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1    42.000000    36.400000      2      2      1   13.33%       8      0
#        2    42.000000    36.400000      2      2      3   13.33%       9      0
#        3    42.000000    36.400000      2      2      3   13.33%      11      0
# a      4    38.000000    36.400000      3      2      4    4.21%       0      0
#        6    38.000000    36.400000      3      2      4    4.21%       9      0
#        7    38.000000    36.400000      3      1      1    4.21%       2      0
#        8    38.000000    36.400000      3      1      3    4.21%       1      0
#        9    38.000000    37.000005      3      0      1    2.63%       2      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.800000000000000e+01
# Final MIP bound                       : 3.800000000000000e+01
#   Solution time / primaldual integral :      0.22s/ 24.054343%
#   Number of solutions found / nodes   :         3 /         9
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 149KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 149KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 2.00e+00,  2.10e+01] / [ 2.00e+00,  2.10e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    70.000000   Time:   0.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  44.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 20 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     20         44.000000      D      0     0        .000000     0
# Dual solved problem
#   20 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.400000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     70.000000    44.400000      1     22      0   36.57%       6      0
#    2  K     70.000000    46.000000      1     13     15   34.29%       8      0
# a           46.000000    46.000000      2                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.600000000000000e+01
# Final MIP bound                       : 4.600000000000000e+01
#   Solution time / primaldual integral :      0.03s/ 85.445930%
#   Number of solutions found / nodes   :         2 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 418KB (peak 451KB, 152KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         52 rows           30 cols          136 elements        30 entities
# Presolved problem has:
#         32 rows           24 cols           96 elements        24 entities
# Presolve finished in 0 seconds
# Heap usage: 455KB (peak 480KB, 152KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  4.00e+00] / [ 2.50e-01,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  3.00e+00] / [ 7.50e-01,  1.00e+00]
#   Objective      [min,max] : [ 3.00e+00,  1.50e+01] / [ 3.00e+00,  1.50e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    40.000000   Time:   0.00    Heuristic: e ***
#  *** Solution found:    32.000000   Time:   0.00    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  32.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 15 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.200000000000000e+01
# Final MIP bound                       : 3.200000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 100.000000%
#   Number of solutions found / nodes   :         2 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 154KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 154KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.50e+01] / [ 1.00e+00,  1.50e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    36.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  32.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 22 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     22         32.000000      D      0     0        .000000     0
# Dual solved problem
#   22 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P           34.000000    32.000000      2                  5.88%       0      0
#    1  K     34.000000    32.400000      2     22      0    4.71%       6      0
#
# Cuts in the matrix         : 22
# Cut elements in the matrix : 70
#
# Performing root presolve...
#
# Reduced problem has:      44 rows      21 columns       120 elements
# Presolve dropped   :      25 rows      14 columns       100 elements
# Presolve tightened :        11 elements
# Will try to keep branch and bound tree memory usage below 7.5GB
# Crash basis containing 4 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     46         32.000000      D      0     0        .000000     0
# Optimal solution found
# Dual solved problem
#   46 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.400000000000000e+01
# Final MIP bound                       : 3.400000000000000e+01
#   Solution time / primaldual integral :      0.05s/ 65.272381%
#   Number of solutions found / nodes   :         2 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 418KB (peak 451KB, 156KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         52 rows           30 cols          136 elements        30 entities
# Presolved problem has:
#         32 rows           24 cols           96 elements        24 entities
# Presolve finished in 0 seconds
# Heap usage: 455KB (peak 480KB, 156KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  4.00e+00] / [ 2.50e-01,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  3.00e+00] / [ 7.50e-01,  1.00e+00]
#   Objective      [min,max] : [ 5.00e+00,  1.80e+01] / [ 5.00e+00,  1.80e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    62.000000   Time:   0.01    Heuristic: e ***
#  *** Solution found:    40.000000   Time:   0.01    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  40.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 11 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.000000000000000e+01
# Final MIP bound                       : 4.000000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 100.000000%
#   Number of solutions found / nodes   :         2 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 158KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 158KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 7.00e+00,  1.90e+01] / [ 7.00e+00,  1.90e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    40.000000   Time:   0.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  40.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 10 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.000000000000000e+01
# Final MIP bound                       : 4.000000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 100.000000%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 161KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 161KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 3.00e+00,  1.70e+01] / [ 3.00e+00,  1.70e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    36.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 10 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 100.000000%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 163KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 163KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  30.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         30.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.000000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           30.000000    30.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.000000000000000e+01
# Final MIP bound                       : 3.000000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 62.556984%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:10, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 166KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 166KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 2.00e+00,  1.90e+01] / [ 2.00e+00,  1.90e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    70.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 18 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     18         36.000000      D      0     0        .000000     0
# Dual solved problem
#   18 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.600000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     70.000000    36.000000      1     33      0   48.57%      12      0
#    2  K     70.000000    36.000000      1      9     28   48.57%       6      0
#    3  K     70.000000    36.000000      1      2      8   48.57%       6      0
#    4  K     70.000000    36.000000      1      8      3   48.57%       7      0
#    5  K     70.000000    36.000000      1      2      7   48.57%       7      0
# ...
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.70e+01] / [ 1.00e+00,  1.70e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    44.000000   Time:   0.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  32.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 18 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#     18         32.000000      D      0     0        .000000     0
# Dual solved problem
#   18 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.200000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K     44.000000    32.514286      1     21      0   26.10%       6      0
#    2  K     44.000000    36.000000      1     27     15   18.18%      12      0
# a           36.000000    36.000000      2                 -0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000001e+01
#   Solution time / primaldual integral :      0.02s/ 81.829268%
#   Number of solutions found / nodes   :         2 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 236KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 236KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.00e+00,  1.80e+01] / [ 1.00e+00,  1.80e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    36.000000   Time:   0.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 10 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 100.000000%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 238KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 238KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 4.00e+00,  1.40e+01] / [ 4.00e+00,  1.40e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    34.000000   Time:   0.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  34.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 9 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.400000000000000e+01
# Final MIP bound                       : 3.400000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 100.000000%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 241KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 241KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 5.00e+00,  1.90e+01] / [ 5.00e+00,  1.90e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    62.000000   Time:   0.01    Heuristic: e ***
#  *** Solution found:    46.000000   Time:   0.01    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  46.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 17 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.600000000000000e+01
# Final MIP bound                       : 4.600000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 100.000000%
#   Number of solutions found / nodes   :         2 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 243KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 243KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  20.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         20.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 2.000000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           20.000000    20.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 2.000000000000000e+01
# Final MIP bound                       : 2.000000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 65.997917%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 400KB (peak 432KB, 245KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         34 rows           20 cols           82 elements        20 entities
# Presolved problem has:
#         20 rows           15 cols           54 elements        15 entities
# Presolve finished in 0 seconds
# Heap usage: 435KB (peak 435KB, 245KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  3.00e+00] / [ 5.00e-01,  1.50e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 3.00e+00,  1.80e+01] / [ 3.00e+00,  1.80e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    38.000000   Time:   0.00    Heuristic: e ***
#  *** Solution found:    36.000000   Time:   0.01    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 10 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000000e+01
#   Solution time / primaldual integral :      0.01s/ 100.000000%
#   Number of solutions found / nodes   :         2 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 427KB (peak 459KB, 248KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         74 rows           42 cols          204 elements        42 entities
# Presolved problem has:
#         47 rows           35 cols          150 elements        35 entities
# Presolve finished in 0 seconds
# Heap usage: 465KB (peak 490KB, 248KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+00] / [ 2.50e-01,  1.25e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 4.00e+00,  2.20e+01] / [ 4.00e+00,  2.20e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 7.5GB
#  *** Solution found:    76.000000   Time:   0.00    Heuristic: e ***
#  *** Solution found:    46.000000   Time:   0.00    Heuristic: k ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  46.000000   .0000000
# -------- cutoff --------
# Concurrent statistics:
#       Dual: 16 simplex iterations, 0.00s
# Problem is cut off
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 4.600000000000000e+01
# Final MIP bound                       : 4.600000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 100.000000%
#   Number of solutions found / nodes   :         2 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 390KB (peak 422KB, 250KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#          6 rows            6 cols           10 elements         6 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 394KB (peak 422KB, 250KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  28.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         28.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 2.800000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           28.000000    28.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 2.800000000000000e+01
# Final MIP bound                       : 2.800000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 52.102763%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# FICO Xpress v9.2.2, Hyper, solve started 9:01:30, Mar 29, 2024
# Heap usage: 396KB (peak 428KB, 252KB system)
# Minimizing MILP Prob using up to 4 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#         20 rows           12 cols           42 elements        12 entities
# Presolved problem has:
#          0 rows            0 cols            0 elements         0 entities
# Presolve finished in 0 seconds
# Heap usage: 401KB (peak 428KB, 252KB system)
# Will try to keep branch and bound tree memory usage below 7.5GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  36.000000   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 0 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      0         36.000000      D      0     0        .000000     0
# Dual solved problem
#   0 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.600000000000000e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# *           36.000000    36.000000      1                  0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.600000000000000e+01
# Final MIP bound                       : 3.600000000000000e+01
#   Solution time / primaldual integral :      0.00s/ 74.784282%
#   Number of solutions found / nodes   :         1 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
